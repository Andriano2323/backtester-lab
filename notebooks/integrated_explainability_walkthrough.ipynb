# %% [markdown]
# # Integrated Explainability Walkthrough
#
# This notebook uses the deterministic integrated-mode fixture from `examples/data/integrated_explain.ndjson` and the testable walkthrough code in `examples/python/integrated_explain_strategy.py`.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
for path in (
    repo_root / "build" / "python",
    repo_root / "python",
    repo_root / "examples" / "python",
):
    if path.exists() and str(path) not in sys.path:
        sys.path.insert(0, str(path))

from integrated_explain_strategy import run_example, trace_summary  # noqa: E402

# %% [markdown]
# ## Mental Model
#
# Each historical L3 event mutates the shared C++ historical LOB, publishes a post-event snapshot, lets the strategy react, validates orders through the gateway, simulates fills against the visible book, updates portfolio state, and records explainability rows.

# %%
result = run_example(explain=True)
result

# %% [markdown]
# ## Result Tables

# %%
result.fills_df

# %%
result.order_log_df

# %%
result.trace_df[["timestamp_ns", "explain_stage", "stage", "event_type", "reason"]]

# %%
trace_summary(result)
